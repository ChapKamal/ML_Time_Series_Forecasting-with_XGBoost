# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from sklearn.metrics import mean_squared_error

color_pal = sns.color_palette()  # define color palette
plt.style.use('fivethirtyeight')

# %% [markdown]
# #### Outline
# - Outlier analysis
# - Forecasting horizon explained
# - Time Series Cross-Validation
# - Log Features
# - Predicting the Future

# %%
filepath = "C:\\Users\\dkhan\\Desktop\\Python\\Machine Learning\\Time_Series\\pjme_hourly.csv"
df = pd.read_csv(filepath)
df = df.set_index('Datetime')
df.index = pd.to_datetime(df.index)

# %%
df.head()
# Out:
#                      PJME_MW
# Datetime
# 2002-12-31 01:00:00  26498.0
# 2002-12-31 02:00:00  25147.0
# 2002-12-31 03:00:00  24574.0
# 2002-12-31 04:00:00  24393.0
# 2002-12-31 05:00:00  24860.0

# %%
df.plot(style='.', 
        figsize=(15,5), 
        color=color_pal[0], 
        title='PJME energy use in MW')
plt.show()

# %%
# in regin between 2012 to 2014, there is a data show very low value. The model will learn from that
# data. If you remove the outlier make sure it has not legitimate role to data.

# %% [markdown]
# #### Outlier Removal and Histogram

# %%
df['PJME_MW'].plot(kind='hist', bins=500)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.query('PJME_MW<20000').plot(figsize=(15,5), style='.')
# Out:
# <Axes: xlabel='Datetime'>

# %%
# The values in the region between 2012 and 2014 are not legitimate. Let's go little less than 20000.

# %%
df.query('PJME_MW < 19000')\
.plot(style='.',
      figsize=(15,5),
      color=color_pal[5],
      title='Outliers')
# Out:
# <Axes: title={'center': 'Outliers'}, xlabel='Datetime'>

# %%
df.query('PJME_MW > 19000').copy()
# Out:
#                      PJME_MW
# Datetime
# 2002-12-31 01:00:00  26498.0
# 2002-12-31 02:00:00  25147.0
# 2002-12-31 03:00:00  24574.0
# 2002-12-31 04:00:00  24393.0
# 2002-12-31 05:00:00  24860.0
# ...                      ...
# 2018-01-01 20:00:00  44284.0
# 2018-01-01 21:00:00  43751.0
# 2018-01-01 22:00:00  42402.0
# 2018-01-01 23:00:00  40164.0
# 2018-01-02 00:00:00  38608.0
#
# [145351 rows x 1 columns]

# %% [markdown]
# #### Reviewing: Train Test Split

# %%
train = df.loc[df.index<'01-01-2015']
test = df.loc[df.index>='01-01-2015']

fig, ax = plt.subplots(figsize=(15,5))
train.plot(ax=ax, label= 'training set', title='Train_Test_Split')
test.plot(ax=ax, label='test set')
ax.axvline('01-01-2015', color='black', ls='--')
ax.legend(['training_set', 'test_set'])
plt.show()
plt.show()

# %% [markdown]
# #### Time Series Cross Validation

# %%
from sklearn.model_selection import TimeSeriesSplit


tss = TimeSeriesSplit(n_splits=5, test_size=24*365*1, gap=24)    # Look at timeseriessplit in sklearn.
                    # test_size for 1 year, gap 24 for training and validation set in each time
df = df.sort_index()

# %%
for train_idx, val_idx in tss.split(df):
    break

# %%
train_idx
# Out:
# array([     0,      1,      2, ..., 101539, 101540, 101541])

# %%
val_idx
# Out:
# array([101566, 101567, 101568, ..., 110323, 110324, 110325])

# %%
fig, axs = plt.subplots(5, 1, figsize=(15, 15),
                       sharex=True)
fold = 0
for train_idx, val_idx in tss.split(df):
    train = df.iloc[train_idx]
    test = df.iloc[val_idx]
    train['PJME_MW'].plot(ax=axs[fold],
                          label='Training Set',
                          title = f'Data Train Test Split Fold{fold}')
    test['PJME_MW'].plot(ax=axs[fold],
                          label='Test Set')
    axs[fold].axvline(test.index.min(), color='black', ls='--')
    fold +=1
plt.show()

# %% [markdown]
# #### Forecasting Horizon Explained

# %%
def create_features(df):
    '''
    create time series features based on time series index.
    '''
    df =df.copy()
    df['hour']=df.index.hour 
    df['dayofweek']=df.index.day_of_week
    df['quarter']=df.index.quarter 
    df['month']=df.index.month
    df['year']=df.index.year
    df['dayofyear']=df.index.dayofyear
    return df

df = create_features(df)

# %% [markdown]
# #### 3. Lag Features

# %%
# what was the target(x) days in the past.

# %%
target_map = df['PJME_MW'].to_dict()

# %%
def add_lags(df):
    df['lag1'] = (df.index-pd.Timedelta('364 days')).map(target_map)   # not 365 beacause 364/7
    df['lag2'] = (df.index-pd.Timedelta('728 days')).map(target_map) 
    df['lag3'] = (df.index-pd.Timedelta('1092 days')).map(target_map)
    return df

# %%
df = add_lags(df)

# %% [markdown]
# #### Train Using Cross Validation

# %%
df.head()
# Out:
#                      PJME_MW  hour  dayofweek  quarter  month  year  \
# Datetime
# 2002-01-01 01:00:00  30393.0     1          1        1      1  2002
# 2002-01-01 02:00:00  29265.0     2          1        1      1  2002
# 2002-01-01 03:00:00  28357.0     3          1        1      1  2002
# 2002-01-01 04:00:00  27899.0     4          1        1      1  2002
# 2002-01-01 05:00:00  28057.0     5          1        1      1  2002
#
#                      dayofyear  lag1  lag2  lag3
# Datetime
# 2002-01-01 01:00:00          1   NaN   NaN   NaN
# 2002-01-01 02:00:00          1   NaN   NaN   NaN
# 2002-01-01 03:00:00          1   NaN   NaN   NaN
# 2002-01-01 04:00:00          1   NaN   NaN   NaN
# 2002-01-01 05:00:00          1   NaN   NaN   NaN

# %%
df.tail()
# Out:
#                      PJME_MW  hour  dayofweek  quarter  month  year  \
# Datetime
# 2018-08-02 20:00:00  44057.0    20          3        3      8  2018
# 2018-08-02 21:00:00  43256.0    21          3        3      8  2018
# 2018-08-02 22:00:00  41552.0    22          3        3      8  2018
# 2018-08-02 23:00:00  38500.0    23          3        3      8  2018
# 2018-08-03 00:00:00  35486.0     0          4        3      8  2018
#
#                      dayofyear     lag1     lag2     lag3
# Datetime
# 2018-08-02 20:00:00        214  42256.0  41485.0  38804.0
# 2018-08-02 21:00:00        214  41210.0  40249.0  38748.0
# 2018-08-02 22:00:00        214  39525.0  38698.0  37330.0
# 2018-08-02 23:00:00        214  36490.0  35406.0  34552.0
# 2018-08-03 00:00:00        215  33539.0  32094.0  31695.0

# %%
tss = TimeSeriesSplit(n_splits=5, test_size=24*365*1, gap=24) 
df = df.sort_index()

folder = 0
preds = []
scores = []

for train_idx, val_idx in tss.split(df):
    train = df.iloc[train_idx]
    test = df.iloc[val_idx]
    train = create_features(train)
    test = create_features(test)
    FEATURES = ['hour', 'dayofweek', 'quarter', 'month', 'year','dayofyear']
    TARGET = 'PJME_MW'
    X_train = train[FEATURES]
    y_train = train[TARGET]
    
    X_test = test[FEATURES]
    y_test = test[TARGET]

    reg =xgb.XGBRegressor(base_score=0.5, booster='gbtree',
                          n_estimators=1000,
                          early_stopping_rounds=50,
                          objective='reg:linear',
                          max_depth=3,
                          learning_rate=0.01) # we use regression test

    reg.fit(X_train, y_train,
            eval_set=[(X_train, y_train), (X_test, y_test)],
            verbose=100)  # gives every 100
    y_pred = reg.predict(X_test)
    preds.append(y_pred)
    score = np.sqrt(mean_squared_error(y_test, y_pred))
    scores.append(score)
# Out:
# [0]	validation_0-rmse:32732.60619	validation_1-rmse:31955.74402
# [100]	validation_0-rmse:12616.26491	validation_1-rmse:11909.76299
# C:\Users\dkhan\anaconda3\Lib\site-packages\xgboost\callback.py:385: UserWarning: [13:03:36] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\objective\regression_obj.cu:277: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [200]	validation_0-rmse:5823.13582	validation_1-rmse:5372.98574
# [300]	validation_0-rmse:3889.53276	validation_1-rmse:3880.48075
# [400]	validation_0-rmse:3421.69696	validation_1-rmse:3732.31208
# [500]	validation_0-rmse:3262.82365	validation_1-rmse:3705.96107
# [600]	validation_0-rmse:3183.38411	validation_1-rmse:3699.21082
# [656]	validation_0-rmse:3150.69139	validation_1-rmse:3705.02729
# [0]	validation_0-rmse:32672.43376	validation_1-rmse:32138.56769
# [100]	validation_0-rmse:12607.30693	validation_1-rmse:12126.07618
# C:\Users\dkhan\anaconda3\Lib\site-packages\xgboost\callback.py:385: UserWarning: [13:03:37] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\objective\regression_obj.cu:277: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [200]	validation_0-rmse:5841.43143	validation_1-rmse:5550.37264
# [300]	validation_0-rmse:3918.41054	validation_1-rmse:3978.41785
# [400]	validation_0-rmse:3457.17630	validation_1-rmse:3704.82907
# [500]	validation_0-rmse:3300.06116	validation_1-rmse:3608.92683
# [600]	validation_0-rmse:3219.85689	validation_1-rmse:3562.10025
# [700]	validation_0-rmse:3168.35398	validation_1-rmse:3526.08803
# [800]	validation_0-rmse:3126.97505	validation_1-rmse:3494.75955
# [900]	validation_0-rmse:3095.26975	validation_1-rmse:3462.52576
# [999]	validation_0-rmse:3068.26517	validation_1-rmse:3447.52655
# [0]	validation_0-rmse:32631.64828	validation_1-rmse:31075.42229
# [100]	validation_0-rmse:12596.92074	validation_1-rmse:11136.29854
# C:\Users\dkhan\anaconda3\Lib\site-packages\xgboost\callback.py:385: UserWarning: [13:03:39] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\objective\regression_obj.cu:277: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [200]	validation_0-rmse:5853.12133	validation_1-rmse:4796.49343
# [300]	validation_0-rmse:3949.30248	validation_1-rmse:3618.51038
# [400]	validation_0-rmse:3480.02985	validation_1-rmse:3571.01649
# [482]	validation_0-rmse:3345.10471	validation_1-rmse:3567.63961
# [0]	validation_0-rmse:32529.08607	validation_1-rmse:31471.02483
# [100]	validation_0-rmse:12565.33046	validation_1-rmse:11684.26857
# C:\Users\dkhan\anaconda3\Lib\site-packages\xgboost\callback.py:385: UserWarning: [13:03:40] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\objective\regression_obj.cu:277: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [200]	validation_0-rmse:5849.44965	validation_1-rmse:5435.95720
# [300]	validation_0-rmse:3952.02204	validation_1-rmse:4153.02167
# [400]	validation_0-rmse:3478.47223	validation_1-rmse:3981.32058
# [500]	validation_0-rmse:3321.01689	validation_1-rmse:3910.40325
# [600]	validation_0-rmse:3245.23066	validation_1-rmse:3880.17332
# [700]	validation_0-rmse:3193.01461	validation_1-rmse:3860.82214
# [800]	validation_0-rmse:3151.17308	validation_1-rmse:3801.05084
# [900]	validation_0-rmse:3120.44022	validation_1-rmse:3771.23932
# [999]	validation_0-rmse:3095.69461	validation_1-rmse:3759.84164
# [0]	validation_0-rmse:32462.89118	validation_1-rmse:31460.19227
# [100]	validation_0-rmse:12546.12885	validation_1-rmse:11657.42929
# C:\Users\dkhan\anaconda3\Lib\site-packages\xgboost\callback.py:385: UserWarning: [13:03:42] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\objective\regression_obj.cu:277: reg:linear is now deprecated in favor of reg:squarederror.
#   self.starting_round = model.num_boosted_rounds()
# [200]	validation_0-rmse:5858.80585	validation_1-rmse:5361.52533
# [300]	validation_0-rmse:3976.95877	validation_1-rmse:4092.75276
# [400]	validation_0-rmse:3513.12746	validation_1-rmse:3971.20149
# [500]	validation_0-rmse:3357.39769	validation_1-rmse:3948.83102
# [600]	validation_0-rmse:3279.08619	validation_1-rmse:3934.92189
# [700]	validation_0-rmse:3229.18809	validation_1-rmse:3916.05216
# [800]	validation_0-rmse:3191.30648	validation_1-rmse:3907.15043
# [825]	validation_0-rmse:3183.31679	validation_1-rmse:3907.78860

# %%
scores
# Out:
# [3698.7023222886064,
#  3447.526551948761,
#  3566.3561846312027,
#  3759.7476643894774,
#  3904.8137258415954]

# %%
print(f'Scores across folds {np.mean(scores):0.4f}') # evaluating by mean method for cross validation
print(f'Fold scores:{scores}')
# Out:
# Scores across folds 3675.4293
# Fold scores:[3698.7023222886064, 3447.526551948761, 3566.3561846312027, 3759.7476643894774, 3904.8137258415954]

# %% [markdown]
# #### 4. Predicting the Future
#
# - Retraining all data
# - To predict future we need an empty dataframe for future data ranges
# - Run those date through our feature creation code + lag creation

# %%
# Retarin all data
df = create_features(df)

FEATURES = ['hour', 'dayofweek', 'quarter', 'month', 'year','dayofyear', 
            'lag1', 'lag2', 'lag3']
TARGET = 'PJME_MW'
X_all = df[FEATURES]
y_all = df[TARGET]

reg =xgb.XGBRegressor(base_score=0.5, booster='gbtree',
                      n_estimators=500,
                      objective='reg:linear',
                      max_depth=3,
                      learning_rate=0.01) # we use regression test

reg.fit(X_all, y_all,
        eval_set=[(X_all, y_all)],
        verbose=100)  # gives every 100
# Out:
# [0]	validation_0-rmse:32402.66145
# C:\Users\dkhan\anaconda3\Lib\site-packages\xgboost\training.py:200: UserWarning: [13:03:44] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\objective\regression_obj.cu:277: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# [100]	validation_0-rmse:12426.65728
# [200]	validation_0-rmse:5753.26464
# [300]	validation_0-rmse:3973.71114
# [400]	validation_0-rmse:3574.05442
# [499]	validation_0-rmse:3459.67006
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=500,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
df.index.max() # Training goes upto max value
# Out:
# Timestamp('2018-08-03 00:00:00')

# %%
# Create Future DataFrame
future = pd.date_range('2018-08-03', '2019-08-01', freq='1h') 
future_df = pd.DataFrame(index=future)
future_df['isFuture']= True
df['isFuture']=False
df_and_future = pd.concat([df, future_df])

# %%
# Above,go upto first day of that month 
# as pour last date so this is end date of our data range. We have to predict hourly, so freq=1h

# %%
df_and_future = create_features(df_and_future)
df_and_future = add_lags(df_and_future)

# %%
df_and_future = pd.concat([df, future_df])
df_and_future = create_features(df_and_future)
df_and_future = add_lags(df_and_future)

# %%
future_with_features = df_and_future.query('isFuture').copy()

# %%
future_with_features
# Out:
#                      PJME_MW  hour  dayofweek  quarter  month  year  \
# 2018-08-03 00:00:00      NaN     0          4        3      8  2018
# 2018-08-03 01:00:00      NaN     1          4        3      8  2018
# 2018-08-03 02:00:00      NaN     2          4        3      8  2018
# 2018-08-03 03:00:00      NaN     3          4        3      8  2018
# 2018-08-03 04:00:00      NaN     4          4        3      8  2018
# ...                      ...   ...        ...      ...    ...   ...
# 2019-07-31 20:00:00      NaN    20          2        3      7  2019
# 2019-07-31 21:00:00      NaN    21          2        3      7  2019
# 2019-07-31 22:00:00      NaN    22          2        3      7  2019
# 2019-07-31 23:00:00      NaN    23          2        3      7  2019
# 2019-08-01 00:00:00      NaN     0          3        3      8  2019
#
#                      dayofyear     lag1     lag2     lag3  isFuture
# 2018-08-03 00:00:00        215  33539.0  32094.0  31695.0      True
# 2018-08-03 01:00:00        215  30781.0  29503.0  29128.0      True
# 2018-08-03 02:00:00        215  29015.0  27712.0  27373.0      True
# 2018-08-03 03:00:00        215  27884.0  26535.0  26233.0      True
# 2018-08-03 04:00:00        215  27223.0  25870.0  25643.0      True
# ...                        ...      ...      ...      ...       ...
# 2019-07-31 20:00:00        212  46912.0  39352.0  40243.0      True
# 2019-07-31 21:00:00        212  45985.0  38699.0  39183.0      True
# 2019-07-31 22:00:00        212  44094.0  37346.0  37759.0      True
# 2019-07-31 23:00:00        212  40666.0  34555.0  34641.0      True
# 2019-08-01 00:00:00        213  37158.0  31646.0  31470.0      True
#
# [8713 rows x 11 columns]

# %% [markdown]
# #### Predict the Future

# %%
future_with_features['pred']=reg.predict(future_with_features[FEATURES])

# %%
future_with_features['pred'].plot(figsize=(15,5),
                                  color=color_pal[4],
                                  ms=1, 
                                  lw=1, 
                                  title='Future Predictions')
# Out:
# <Axes: title={'center': 'Future Predictions'}>

# %% [markdown]
# #### Save model for Later

# %%
# save model 1
reg.save_model('model.jason')
# Out:
# C:\Users\dkhan\anaconda3\Lib\site-packages\xgboost\sklearn.py:1116: UserWarning: [13:28:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\c_api\c_api.cc:1573: Saving model in the UBJSON format as default.  You can use a file extension: `json` or `ubj` to choose between formats.
#   self.get_booster().save_model(fname)

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 2094-2431
#
#  Directory of C:\Users\dkhan\Desktop\Python\Machine Learning\Time_Series
#
# 03/20/2026  01:29 PM    <DIR>          .
# 03/19/2026  06:06 PM    <DIR>          ..
# 03/20/2026  11:10 AM    <DIR>          .ipynb_checkpoints
# 03/20/2026  01:28 PM           585,395 model.jason
# 03/19/2026  07:26 PM         4,070,265 PJME_hourly.csv
# 03/19/2026  06:15 PM         3,130,960 spain_energy_market.csv
# 03/20/2026  01:29 PM           987,481 Time Series Broadcasting with XGBoost_Advanced_Method.ipynb
# 03/20/2026  11:40 AM           972,199 Time_Series_Forecasting with_XGBoost.ipynb
#                5 File(s)      9,746,300 bytes
#                3 Dir(s)  287,931,338,752 bytes free

# %%
reg_new = xgb.XGBRegressor()
reg_new.load_model('model.jason')

future_with_features['pred']=reg_new.predict(future_with_features[FEATURES]) # change reg to reg_new
future_with_features['pred'].plot(figsize=(15,5),
                                  color=color_pal[4],
                                  ms=1, 
                                  lw=1, 
                                  title='Future Predictions')
# Out:
# C:\Users\dkhan\anaconda3\Lib\site-packages\xgboost\sklearn.py:1125: UserWarning: [13:36:57] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\c_api\c_api.cc:1509: Unknown file format: `jason`. Using UBJSON (`ubj`) as a guess.
#   self.get_booster().load_model(fname)
# <Axes: title={'center': 'Future Predictions'}>
